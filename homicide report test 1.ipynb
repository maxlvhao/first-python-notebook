# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
FullReport = pd.read_csv("/Users/maaaaax/Code/homicide.latimes.com/homicide_export.csv")

# %%
FullReport.head()
# Out:
#       ID coroners case number police case number da case number  \
# 0  16677           2018-06232                NaN            NaN
# 1  16678           2018-06233                NaN            NaN
# 2  16676           2018-06226                NaN            NaN
# 3  16674           2018-06146                NaN            NaN
# 4  16675           2018-06079                NaN            NaN
#
#                        slug first name middle name last name suffix  \
# 0         robert-salinas-jr     Robert         NaN   Salinas    Jr.
# 1  jeremy-alexander-henness     Jeremy   Alexander   Henness    NaN
# 2     anthony-daniel-vargas    Anthony      Daniel    Vargas    NaN
# 3       yuri-rayma-arellano       Yuri       Rayma  Arellano    NaN
# 4   maria-anastacia-ventura      Maria   Anastacia   Ventura    NaN
#
#    death date  ...  incident zipcode  officer involved ruling  \
# 0  2018-08-12  ...           91766.0             False      H
# ...

# %%
FullReport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16142 entries, 0 to 16141
# Data columns (total 31 columns):
# ID                      16142 non-null int64
# coroners case number    16140 non-null object
# police case number      10559 non-null object
# da case number          933 non-null object
# slug                    16142 non-null object
# first name              16142 non-null object
# middle name             9129 non-null object
# last name               16139 non-null object
# suffix                  1001 non-null object
# death date              16142 non-null object
# death time              8601 non-null object
# age                     16112 non-null float64
# date of birth           15585 non-null object
# cause                   15662 non-null object
# security hold           16142 non-null bool
# Have autopsy?           16142 non-null bool
# gender                  16114 non-null object
# race                    15991 non-null object
# ...

# %%
FullReport.age.head()
# Out:
# 0    37.0
# 1    31.0
# 2    21.0
# 3    33.0
# 4    57.0
# Name: age, dtype: float64

# %%
youth=FullReport[ FullReport.age < 19]

# %%
youth.head()
# Out:
#        ID coroners case number police case number da case number  \
# 41  16608           2018-05354                NaN            NaN
# 56  16621           2018-05088       180705000256            NaN
# 60  16618           2018-05073                NaN            NaN
# 68  16581           2018-04977           18-44523       VA148107
# 87  16569           2018-04725                NaN            NaN
#
#                         slug first name  middle name  last name suffix  \
# 41                makani-waz     Makani          NaN        Waz    NaN
# 56        ruben-alcantara-jr      Ruben          NaN  Alcantara    Jr.
# 60  demya-beatris-rae-martin      Demya  Beatris Rae     Martin    NaN
# 68    ivan-garcia-2018-04977       Ivan          NaN     Garcia    NaN
# 87            anthony-avalos    Anthony          NaN     Avalos    NaN
#
#     death date                        ...                          \
# 41  2018-07-11                        ...
# ...

# %%
youth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2413 entries, 41 to 16137
# Data columns (total 31 columns):
# ID                      2413 non-null int64
# coroners case number    2412 non-null object
# police case number      1572 non-null object
# da case number          137 non-null object
# slug                    2413 non-null object
# first name              2413 non-null object
# middle name             1105 non-null object
# last name               2412 non-null object
# suffix                  139 non-null object
# death date              2413 non-null object
# death time              1162 non-null object
# age                     2413 non-null float64
# date of birth           2289 non-null object
# cause                   2234 non-null object
# security hold           2413 non-null bool
# Have autopsy?           2413 non-null bool
# gender                  2400 non-null object
# race                    2370 non-null object
# died on scene           2413 non-null bool
# ...

# %%
youth.groupby("age", axis=0).sum().reset_index()
# Out:
#      age       ID  security hold  Have autopsy?  died on scene  \
# 0    0.0  2145680            0.0            0.0            2.0
# 1    1.0   592460            1.0            1.0            2.0
# 2    2.0   385520            0.0            0.0            0.0
# 3    3.0   325900            0.0            1.0            1.0
# 4    4.0   240055            1.0            1.0            0.0
# 5    5.0   109995            0.0            0.0            0.0
# 6    6.0    75697            0.0            0.0            0.0
# 7    7.0   110868            0.0            0.0            0.0
# 8    8.0   128654            1.0            0.0            0.0
# 9    9.0    60257            0.0            0.0            0.0
# 10  10.0   114171            0.0            0.0            0.0
# 11  11.0    98376            0.0            0.0            1.0
# 12  12.0   137730            0.0            0.0            0.0
# 13  13.0   286933            0.0            0.0            2.0
# ...
